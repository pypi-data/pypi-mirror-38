# %%
# %matplotlib inline
import pandas as pd
import lifelines
import matplotlib.pyplot as plt

plt.style.use('seaborn-colorblind')
plt.rcParams['figure.figsize'] = (14.0, 6.0)

# %%
raw_df = pd.read_csv("/Users/camerondavidson-pilon/Downloads/Parliamentarians.csv")

# %%
raw_df.head()
# Out:
#                            Name Province/Region of Birth  \
# 0      Abbott, Anthony Chisholm                   Quebec
# 1       Abbott, Douglas Charles                   Quebec
# 2                   Abbott, Jim                  Ontario
# 3  Abbott, John Joseph Caldwell
# 4               Ablonczy, Diane                 Illinois
#
#                              Type of Parliamentarian  \
# 0                       MP (1974/07/08 - 1979/05/21)
# 1  MP (1953/08/10 - 1954/06/30)MP (1949/06/27 - 1...
# 2  MP (1997/06/02 - 2011/05/01)MP (1993/10/25 - 1...
# 3  MP (1881/08/17 - 1887/02/21)MP (1880/02/12 - 1...
# 4  MP (1997/06/02 - 2015/10/18)MP (1993/10/25 - 1...
#
#                           Riding/Senatorial Division  \
# 0              Mississauga (1974/07/08 - 1979/05/21)
# 1  Saint-Antoine--Westmount (1953/08/10 - 1954/06...
# 2  Kootenay--Columbia (1997/06/02 - 2011/05/01)Ko...
# 3  Inkerman (1887/05/12 - 1893/10/30)Argenteuil (...
# 4  Calgary Nose Hill (1997/06/02 - 2015/10/18)Cal...
#
#                  Province/Territory Gender               Profession  \
# 0                           Ontario      M                   lawyer
# 1                QuebecQuebecQuebec      M                   lawyer
# 2  British ColumbiaBritish Columbia      M     manager, businessman
# 3          QuebecQuebecQuebecQuebec      M  professor, lawyer, dean
# 4                    AlbertaAlberta      F  farmer, lawyer, teacher
#
#                                Political Affiliation  \
# 0  Liberal Party of Canada (1974/07/08 - 1979/05/21)
# 1  Liberal Party of Canada (1940/03/26 - 1954/06/30)
# 2  Conservative Party of Canada (2003/12/23 - 201...
# 3  Liberal-Conservative (1887/05/12 - 1893/10/30)...
# 4  Conservative Party of Canada (2003/12/23 - 201...
#
#   Date Appointed/Date of First Election  \
# 0                            1974-07-08
# 1                            1940-03-26
# 2                            1993-10-25
# 3                            1867-09-20
# 4                            1993-10-25
#
#                            Years of Service  Military Service
# 0   1778 days (4 years, 10 months, 13 days)               NaN
# 1    5207 days (14 years, 3 months, 3 days)               NaN
# 2    6396 days (17 years, 6 months, 4 days)               NaN
# 3   7467 days (20 years, 5 months, 10 days)               NaN
# 4  8027 days (21 years, 11 months, 22 days)               NaN

# %%
df = raw_df.drop(['Name', 'Riding/Senatorial Division', 'Province/Territory', 
                  'Political Affiliation', 
                  'Military Service', 'Province/Region of Birth'], axis=1).dropna()

# %%
import re


def parse_years_of_service(s):
    return int(re.search("(\d*) days", s).group(1))
  
def parse_year_of_first_date_appointed(s):
    return s[:4]
    
def parse_Type_of_Parliamentarian_if_censored(s):
    if re.search("\(\d{4}/\d{2}/\d{2} - \)", s):
        return False
    return True
    
df['left_office?'] = df['Type of Parliamentarian'].map(parse_Type_of_Parliamentarian_if_censored)
df['days'] = df['Years of Service'].map(parse_years_of_service)
df['year_first_appointed'] = df['Date Appointed/Date of First Election'].map(parse_year_of_first_date_appointed)
df['decade_first_appointed'] = df['year_first_appointed'].str.slice(0,3) + 'x'


df = df.drop(['Years of Service', 'Type of Parliamentarian', 'Date Appointed/Date of First Election'], axis=1)

# %%
df.head()
# Out:
#   Gender               Profession  left_office?  days year_first_appointed  \
# 0      M                   lawyer          True  1778                 1974
# 1      M                   lawyer          True  5207                 1940
# 2      M     manager, businessman          True  6396                 1993
# 3      M  professor, lawyer, dean          True  7467                 1867
# 4      F  farmer, lawyer, teacher          True  8027                 1993
#
#   decade_first_appointed
# 0                   197x
# 1                   194x
# 2                   199x
# 3                   186x
# 4                   199x

# %%
kmf = lifelines.KaplanMeierFitter()
kmf.fit(df['days'], df['left_office?'])
kmf.plot()

# %%
ax = plt.subplot(111
                )
for label, g in df.groupby('Gender'):
    kmf.fit(g['days'], g['left_office?'], label=label)
    kmf.plot(ax=ax)

# %%
ax = plt.subplot(111)

for label, g in df.groupby('decade_first_appointed'):
    kmf.fit(g['days'], g['left_office?'], label=label)
    if label == '200x' or label == '201x' or label == '199x':
        kmf.plot(ax=ax, ci_show=False)
    else:
        kmf.plot(ax=ax, c='k', alpha=0.15, ci_show=False)

# %%
kmf.plot?
