# %% [markdown]
# ## Create code snippets

# %%
from ipyrest.codegen import create_code, python_requests_template
config = dict(
        method='GET',
        url='https://api-lookup.data.api.platform.here.com/lookup/v1/platform/apis',
        headers={'Authorization': 'Bearer ' + get_olp_token('/Users/gherman/.here/credentials.properties')},
        # params={'foo': 42},
        # data='XXX'
    )
snippet = create_code(python_requests_template, config)
print(snippet)
# Out:
# # Automatically generated by ipyrest, see github.com/deeplook/ipyrest
#
# method = 'GET'
# url = 'https://api-lookup.data.api.platform.here.com/lookup/v1/platform/apis'
# ...

# %%
from ipyrest.codegen import create_code_from_api
snippet = create_code_from_api(python_requests_template, api)
print(snippet)
# Out:
# # Automatically generated by ipyrest, see github.com/deeplook/ipyrest
#
# method = 'get'
# url = 'https://api-lookup.data.api.platform.here.com/lookup/v1/platform/apis'
# ...

# %%
from requests import request
method = 'get'
url = 'https://api-lookup.data.api.platform.here.com/lookup/v1/platform/apis'
headers = {'Authorization': 'Bearer eyJhbGciOiJSUzUxMiIsImN0eSI6IkpXVCIsImlzcyI6IkhFUkUiLCJhaWQiOiJFMXJKMDRRT2sxTEdPaDJyUjlrQiIsImlhdCI6MTU0MjM2MzAzMywiZXhwIjoxNTQyNDQ5NDMzLCJraWQiOiJqMSJ9..oP6OGNu5nO_5U04P894HNUt3vPqFAHkf6ap3GspELiXxx5ng99ZuOE5JsDxaX-t15vqkAEP8eBd-V1-2JrYJ_S-D9zsnPrkFN0GmqaC2EOFRFN_6GS3nqcDqsGY11EQp_HN8H_-L2MUhgEWioBrEqme4ZlvizI_n0NKXp3LEhwSXSKiYryH06W7Qx9RI8nLn8KA2OLQYJbVlRVBcmSd068wGs5_UxRVbi5LtFfYVSDb62DBycEWjLf2lrgVhOkYMAek_y9ypXJ4oLtBX3fRRqso-_fjW67oTLu0kESNPk3DrWmxbTamYhLwsVQDAZ9mtevx3hb5bTNg08FQoYbbzSQ'}

response = request(method, url, headers=headers)
print(response.text)
# Out:
# [{"api":"config","version":"v1","baseURL":"https://config.data.api.platform.here.com/config/v1","parameters":{}},{"api":"pipelines","version":"v2","baseURL":"https://pipelines.api.platform.here.com/pipeline-service","parameters":{}}]
